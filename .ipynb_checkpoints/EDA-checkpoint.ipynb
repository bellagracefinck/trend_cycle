# %%
import pandas as pd
from io import StringIO
from bs4 import BeautifulSoup as bs
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import re
import numpy as np
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# %% [markdown]
# ### Read in datasets

# %%
collections = pd.read_csv('collections.csv').drop(columns = ['Unnamed: 0'])
collections = collections.sort_values('designer').sort_values('seasonyear')
collections['id'] = collections.index
collections.head()
# Out:
#    season  year  seasonyear           designer  \
# 0  spring  1990      1990.0     azzedine-alaia
# 1  spring  1990      1990.0        romeo-gigli
# 2    fall  1990      1990.1     azzedine-alaia
# 3  spring  1991      1991.0     azzedine-alaia
# 4  spring  1991      1991.0  comme-des-garcons
#
#                                                 text  \
# 0  An enfilade of stretchy knits in jewel tones w...
# 1  Romeo Gigli is having a moment. The designer’s...
# 2  Alaïa worked with pinstripes and other power m...
# 3  <a href="https://www.vogue.com/article/bella-h...
# 4  “Comme des Garçons,” Rei Kawakubo told <em>Vog...
#
#                               preprocessed_sentences  consistency  prevalence  \
# 0  enfilad stretchi knit jewel tone effect showma...     0.235294    0.172794
# 1  moment design signatur cocoon shape gigliana f...     0.014706   -0.985294
# 2  work pinstrip power materi season time spot re...     0.235294    0.172794
# 3  hadid remind follow timeless appeal april appe...     0.235294    0.172794
# 4  rei kawakubo told gift oneself appeal attract ...     0.984848    0.969464
#
#    class  id
# 0      4   0
# 1      0   1
# 2      4   2
# 3      4   3
# 4     10   4

# %%
collections.shape
# Out:
# (14261, 10)

# %%
designers = pd.read_csv('designers.csv').drop(columns = ['Unnamed: 0'])
designers.head()
# Out:
#             designer  collections  first_season  consistency  prevalence  \
# 0  comme-des-garcons           65        1991.0     0.984848    0.969464
# 1            versace           61        1991.0     0.924242    0.907849
# 2  alexander-mcqueen           57        1995.0     0.982759    0.965215
# 3              prada           57        1992.0     0.890625    0.873081
# 4            miu-miu           55        1995.1     0.964912    0.946730
#
#    class
# 0     10
# 1      8
# 2     10
# 3      8
# 4      9

# %%
designers.shape
# Out:
# (1285, 6)

# %% [markdown]
# ### Exploratory data analysis & visualizations

# %%
collections_per_year = collections.groupby(collections['year']).size()

# Plotting
plt.figure(figsize=(10, 6))
collections_per_year.plot(kind='line', marker='o', color='palevioletred')
plt.title('Number of Collections per Year')
plt.xlabel('Year')
plt.ylabel('Number of Collections')
plt.grid(True)
plt.xticks(collections_per_year.index, rotation=45)
plt.tight_layout()
plt.show()

# %%
# plot the distributions of classes, collections, and first seasons
fig, ax = plt.subplots(2, 2, figsize=(20, 16))

# distribution of total collections
sns.histplot(data=designers,color = 'palevioletred', x = 'collections', bins="auto", ax = ax[0,0])
ax[0,0].set_title('# of Collections per designer', fontdict = {'fontsize': 15, 'fontweight':'bold'})
ax[0,0].set_xlabel('Total Collections', fontsize = 12, fontweight='bold') 
ax[0,0].set_ylabel('Count', fontsize = 12, fontweight='bold') 

# distribution of initial seasons 
sns.histplot(data=designers, color = 'palevioletred',x = 'first_season', ax = ax[0,1])
ax[0,1].set_xlim(1990,2025)
ax[0,1].set_title('First seasons by designer', fontdict = {'fontsize': 15, 'fontweight':'bold'})
ax[0,1].set_xlabel('First season', fontsize = 12, fontweight='bold') 
ax[0,1].set_ylabel('Count', fontsize = 12, fontweight='bold') 

# distribution of prevalance scores 
sns.histplot(data=designers, color = 'navy', x = 'prevalence', bins="auto", ax = ax[1,1])
ax[1,1].set_title('Prevalence scores', fontdict = {'fontsize': 15, 'fontweight':'bold'})
ax[1,1].set_xlabel('Prevalence', fontsize = 12, fontweight='bold') 
ax[1,1].set_ylabel('Count', fontsize = 12, fontweight='bold') 

# distribution of consistency scores 
sns.histplot(data=designers,color ='navy', x = 'consistency', bins="auto", ax = ax[1,0])
ax[1,0].set_title('Consistency scores', fontdict = {'fontsize': 15, 'fontweight':'bold'})
ax[1,0].set_xlabel('Consistency', fontsize = 12, fontweight='bold') 
ax[1,0].set_ylabel('Count', fontsize = 12, fontweight='bold') 

# Set the same y-axis limits for bottom two plots
ax[1,0].set_ylim(0, 300)
ax[1,1].set_ylim(0, 300)

plt.show()

# %%
from nltk.tokenize import word_tokenize
preprocessed = [sentence for sentence in collections['preprocessed_sentences']]
collections['tokens'] = [word_tokenize(sentence) for sentence in preprocessed]

# %%
# plot the token length distribution using pandas

collections['tokens'].apply(len).hist(bins=20, edgecolor = 'black', color='palevioletred')
plt.title('Collection review length (token count) distribution',fontdict = {'fontsize': 12, 'fontweight':'bold'})
plt.xlabel('Token length')
plt.grid(False)
plt.ylabel('Frequency')
plt.show()

# %%
# token df
sample_tokens = (collections[['id','tokens']].explode('tokens'))
sample_tokens.head()
# Out:
#    id    tokens
# 0   0   enfilad
# 0   0  stretchi
# 0   0      knit
# 0   0     jewel
# 0   0      tone

# %%
from wordcloud import WordCloud
stopwords = ['season','wai','good','pair','year','felt','focu','start','make', 'look','men','littl','present','fabric','girl','shape','includ', 'collect', 'show','wear','women','runwai','model', 'think','color','want','feel', 'inspir','come', 'fall','spring', 'work', 'show','like', 'todai','came','thing', 'look','design','cloth','piec','time','work','said','style','idea','turn']
wc = WordCloud(stopwords = stopwords, background_color="white", max_font_size= 300,  width=1600, height=800).generate(' '.join(sample_tokens['tokens']))

plt.figure(figsize=(50,30))
plt.imshow(wc, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# !pip install nltk
# Out:
# Requirement already satisfied: nltk in /Users/bellagracefinck/anaconda3/lib/python3.11/site-packages (3.8.1)
# Requirement already satisfied: click in /Users/bellagracefinck/anaconda3/lib/python3.11/site-packages (from nltk) (8.0.4)
# Requirement already satisfied: joblib in /Users/bellagracefinck/anaconda3/lib/python3.11/site-packages (from nltk) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/bellagracefinck/anaconda3/lib/python3.11/site-packages (from nltk) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/bellagracefinck/anaconda3/lib/python3.11/site-packages (from nltk) (4.65.0)

# %%
from nltk import pos_tag, word_tokenize
text = [token.lower() for token in word_tokenize(collections['text'][13293])]
pos_tag(text)
# Out:
# [('true', 'JJ'),
#  ('to', 'TO'),
#  ('her', 'PRP$'),
#  ('italian', 'JJ'),
#  ('roots', 'NNS'),
#  (',', ','),
#  ('camille', 'NN'),
#  ('miceli', 'NN'),
#  ('called', 'VBN'),
#  ('pucci', 'NN'),
#  ('’', 'NN'),
#  ('s', 'VBP'),
#  ('winter', 'NN'),
#  ('collection', 'NN'),
#  ('<', 'NNP'),
#  ('em', 'VBZ'),
#  ('>', 'NNP'),
#  ('la', 'NNP'),
#  ('piazzetta', 'FW'),
#  ('<', 'NNP'),
#  ('/em', 'NNP'),
#  ('>', 'NNP'),
#  (',', ','),
#  ('hinting', 'VBG'),
#  ('not', 'RB'),
#  ('only', 'RB'),
#  ('at', 'IN'),
#  ('capri', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('famous', 'JJ'),
#  ('handkerchief-sized', 'JJ'),
#  ('hotspot', 'NN'),
#  (',', ','),
#  ('but', 'CC'),
#  ('also', 'RB'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('notion', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('city', 'NN'),
#  ('square', 'NN'),
#  ('as', 'IN'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('italian', 'JJ'),
#  ('culture', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('space', 'NN'),
#  ('open', 'JJ'),
#  ('to', 'TO'),
#  ('communality', 'NN'),
#  ('and', 'CC'),
#  ('connections', 'NNS'),
#  ('.', '.'),
#  ('these', 'DT'),
#  ('values', 'NNS'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('idea', 'NN'),
#  ('of', 'IN'),
#  ('<', 'JJ'),
#  ('em', 'FW'),
#  ('>', 'FW'),
#  ('la', 'FW'),
#  ('famiglia', 'FW'),
#  ('<', 'FW'),
#  ('/em', 'FW'),
#  ('>', 'NNP'),
#  (',', ','),
#  ('another', 'DT'),
#  ('established', 'VBN'),
#  ('building', 'NN'),
#  ('block', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('italian', 'JJ'),
#  ('lifestyle', 'NN'),
#  (',', ','),
#  ('are', 'VBP'),
#  ('the', 'DT'),
#  ('drivers', 'NNS'),
#  ('miceli', 'VBP'),
#  ('is', 'VBZ'),
#  ('embracing', 'VBG'),
#  ('to', 'TO'),
#  ('charge', 'VB'),
#  ('pucci', 'NN'),
#  ('with', 'IN'),
#  ('a', 'DT'),
#  ('bold', 'JJ'),
#  ('new', 'JJ'),
#  ('energy.', 'NN'),
#  ('<', 'NNP'),
#  ('/p', 'NNP'),
#  ('>', 'NNP'),
#  ('<', 'NNP'),
#  ('p', 'NN'),
#  ('>', 'NNP'),
#  ('miceli', 'NN'),
#  ('drew', 'NN'),
#  ('from', 'IN'),
#  ('her', 'PRP$'),
#  ('own', 'JJ'),
#  ('family', 'NN'),
#  ('and', 'CC'),
#  ('circle', 'NN'),
#  ('of', 'IN'),
#  ('friends—a', 'JJ'),
#  ('motley', 'NN'),
#  ('crew', 'NN'),
#  ('of', 'IN'),
#  ('characters', 'NNS'),
#  (',', ','),
#  ('talents', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('generations—for', 'VB'),
#  ('the', 'DT'),
#  ('winter', 'NN'),
#  ('collection', 'NN'),
#  (',', ','),
#  ('generously', 'RB'),
#  ('sprinkling', 'VBG'),
#  ('it', 'PRP'),
#  ('with', 'IN'),
#  ('her', 'PRP'),
#  ('abundant', 'JJ'),
#  ('<', 'JJ'),
#  ('em', 'NN'),
#  ('>', 'NNP'),
#  ('joie', 'NN'),
#  ('de', 'FW'),
#  ('vivre', 'FW'),
#  ('<', 'FW'),
#  ('/em', 'FW'),
#  ('>', 'FW'),
#  ('.', '.'),
#  ('“', 'VB'),
#  ('my', 'PRP$'),
#  ('pucci', 'NN'),
#  ('woman', 'NN'),
#  ('is', 'VBZ'),
#  ('an', 'DT'),
#  ('urban', 'JJ'),
#  ('bohemian', 'NN'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('loves', 'VBZ'),
#  ('to', 'TO'),
#  ('travel', 'VB'),
#  (',', ','),
#  ('she', 'PRP'),
#  ('’', 'VBD'),
#  ('s', 'NN'),
#  ('in', 'IN'),
#  ('constant', 'JJ'),
#  ('movement', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('she', 'PRP'),
#  ('says', 'VBZ'),
#  ('.', '.'),
#  ('“', 'VB'),
#  ('it', 'PRP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('the', 'DT'),
#  ('mother', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('’', 'VBZ'),
#  ('s', 'PDT'),
#  ('the', 'DT'),
#  ('daughter', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('’', 'VBZ'),
#  ('s', 'PDT'),
#  ('the', 'DT'),
#  ('grandma—as', 'NN'),
#  ('long', 'RB'),
#  ('as', 'IN'),
#  ('they', 'PRP'),
#  ('enjoy', 'VBP'),
#  ('life', 'NN'),
#  (',', ','),
#  ('they', 'PRP'),
#  ('’', 'VBP'),
#  ('re', 'JJ'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('community', 'NN'),
#  ('of', 'IN'),
#  ('pucci.', 'NN'),
#  ('”', 'NNP'),
#  ('<', 'NNP'),
#  ('/p', 'NNP'),
#  ('>', 'NNP'),
#  ('<', 'NNP'),
#  ('p', 'NN'),
#  ('>', 'NNP'),
#  ('festive', 'NN'),
#  (',', ','),
#  ('bold', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('colorful', 'NN'),
#  (',', ','),
#  ('the', 'DT'),
#  ('collection', 'NN'),
#  ('keeps', 'VBZ'),
#  ('all', 'PDT'),
#  ('the', 'DT'),
#  ('label', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('fundamentals', 'NNS'),
#  ('alive', 'JJ'),
#  (',', ','),
#  ('while', 'IN'),
#  ('introducing', 'VBG'),
#  ('a', 'DT'),
#  ('few', 'JJ'),
#  ('novelty', 'NN'),
#  ('notes', 'NNS'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('mix', 'NN'),
#  ('.', '.'),
#  ('knitwear', 'NN'),
#  ('was', 'VBD'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('addition', 'NN'),
#  (',', ','),
#  ('offered', 'VBN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('rainbow-colored', 'JJ'),
#  ('capelet', 'NN'),
#  ('with', 'IN'),
#  ('an', 'DT'),
#  ('undulating', 'VBG'),
#  ('hem', 'NN'),
#  (',', ','),
#  ('or', 'CC'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('fringed', 'JJ'),
#  ('hand-knitted', 'JJ'),
#  (',', ','),
#  ('patch-worked', 'JJ'),
#  ('poncho', 'NN'),
#  ('worked', 'VBD'),
#  ('with', 'IN'),
#  ('horizontal', 'JJ'),
#  ('intarsia', 'NN'),
#  ('.', '.'),
#  ('miceli', 'NN'),
#  ('said', 'VBD'),
#  ('that', 'IN'),
#  ('she', 'PRP'),
#  ('was', 'VBD'),
#  ('“', 'RB'),
#  ('happy', 'JJ'),
#  ('to', 'TO'),
#  ('have', 'VB'),
#  ('achieved', 'VBN'),
#  ('something', 'NN'),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('pucci', 'JJ'),
#  (',', ','),
#  ('without', 'IN'),
#  ('being', 'VBG'),
#  ('logo-ed', 'JJ'),
#  ('by', 'IN'),
#  ('the', 'DT'),
#  ('prints', 'NNS'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('big', 'JJ'),
#  ('way.', 'NN'),
#  ('”', 'NN'),
#  ('she', 'PRP'),
#  ('also', 'RB'),
#  ('used', 'VBD'),
#  ('black', 'JJ'),
#  ('as', 'IN'),
#  ('a', 'DT'),
#  ('thread', 'NN'),
#  ('throughout', 'IN'),
#  ('the', 'DT'),
#  ('collection', 'NN'),
#  (',', ','),
#  ('using', 'VBG'),
#  ('prints', 'NNS'),
#  ('as', 'IN'),
#  ('pipings', 'NNS'),
#  (',', ','),
#  ('side', 'NN'),
#  ('inserts', 'NNS'),
#  (',', ','),
#  ('foulard', 'JJ'),
#  ('ribbons', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('fringes', 'NNS'),
#  (',', ','),
#  ('while', 'IN'),
#  ('widening', 'VBG'),
#  ('the', 'DT'),
#  ('color', 'NN'),
#  ('palette', 'NN'),
#  ('with', 'IN'),
#  ('“', 'NNP'),
#  ('some', 'DT'),
#  ('more', 'RBR'),
#  ('options', 'NNS'),
#  ('that', 'WDT'),
#  ('reflect', 'VBP'),
#  ('its', 'PRP$'),
#  ('character', 'NN'),
#  ('without', 'IN'),
#  ('being', 'VBG'),
#  ('necessarily', 'RB'),
#  ('full-on', 'JJ'),
#  ('printed.', 'NN'),
#  ('”', 'NNP'),
#  ('<', 'NNP'),
#  ('/p', 'NNP'),
#  ('>', 'NNP'),
#  ('<', 'NNP'),
#  ('div', 'NN'),
#  ('class=', 'NN'),
#  ("''", "''"),
#  ('adwrapper-dqtivb', 'JJ'),
#  ('fzrssq', 'NN'),
#  ('ad', 'NN'),
#  ('ad', 'NN'),
#  ('--', ':'),
#  ('in-content', 'JJ'),
#  ("''", "''"),
#  ('>', 'NN'),
#  ('<', 'NNP'),
#  ('div', 'NN'),
#  ('class=', 'NN'),
#  ("''", "''"),
#  ('ad__slot', 'NN'),
#  ('ad__slot', 'NN'),
#  ('--', ':'),
#  ('in-content', 'JJ'),
#  ("''", "''"),
#  ('data-node-id=', 'NN'),
#  ("''", "''"),
#  ('yt1iwh', 'NN'),
#  ("''", "''"),
#  ('>', 'CC'),
#  ('<', 'NNP'),
#  ('/div', 'NNP'),
#  ('>', 'NNP'),
#  ('<', 'NNP'),
#  ('/div', 'NNP'),
#  ('>', 'NNP'),
#  ('<', 'NNP'),
#  ('p', 'NN'),
#  ('>', 'NN'),
#  ('fringes', 'NNS'),
#  ('are', 'VBP'),
#  ('a', 'DT'),
#  ('miceli', 'JJ'),
#  ('signature', 'NN'),
#  (',', ','),
#  ('as', 'IN'),
#  ('they', 'PRP'),
#  ('“', 'VBP'),
#  ('bring', 'VBG'),
#  ('frivolity', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('garment', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('she', 'PRP'),
#  ('explained', 'VBD'),
#  ('.', '.'),
#  ('they', 'PRP'),
#  ('also', 'RB'),
#  ('give', 'VBP'),
#  ('the', 'DT'),
#  ('feel', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('energy', 'NN'),
#  ('and', 'CC'),
#  ('glamour', 'NN'),
#  ('that', 'WDT'),
#  ('is', 'VBZ'),
#  ('the', 'DT'),
#  ('quintessential', 'JJ'),
#  ('combination', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('pucci-miceli', 'JJ'),
#  ('connection', 'NN'),
#  ('.', '.'),
#  ('the', 'DT'),
#  ('pucci', 'NN'),
#  ('woman', 'NN'),
#  (',', ','),
#  ('whatever', 'WDT'),
#  ('her', 'PRP$'),
#  ('age', 'NN'),
#  (',', ','),
#  ('is', 'VBZ'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('move', 'NN'),
#  (',', ','),
#  ('going', 'VBG'),
#  ('around', 'IN'),
#  ('in', 'IN'),
#  ('activewear-inspired', 'JJ'),
#  ('zippered', 'JJ'),
#  ('blousons', 'NNS'),
#  ('in', 'IN'),
#  ('shiny', 'NN'),
#  ('recycled', 'VBD'),
#  ('nylon', 'RB'),
#  ('printed', 'VBN'),
#  ('and', 'CC'),
#  ('tiny', 'JJ'),
#  ('pleated', 'VBN'),
#  ('printed', 'JJ'),
#  ('kilts', 'NNS'),
#  (',', ','),
#  ('and', 'CC'),
#  ('weathering', 'VBG'),
#  ('rainy', 'JJ'),
#  ('days', 'NNS'),
#  ('in', 'IN'),
#  ('protective', 'JJ'),
#  ('hooded', 'VBD'),
#  ('waxed', 'JJ'),
#  ('ponchos', 'NN'),
#  ('boasting', 'VBG'),
#  ('the', 'DT'),
#  ('lysergic', 'JJ'),
#  ('<', 'NNP'),
#  ('em', 'NN'),
#  ('>', 'NNP'),
#  ('marmo', 'NN'),
#  ('<', 'NNP'),
#  ('/em', 'NNP'),
#  ('>', 'NNP'),
#  ('pattern.', 'NN'),
#  ('<', 'NNP'),
#  ('/p', 'NNP'),
#  ('>', 'NNP'),
#  ('<', 'NNP'),
#  ('p', 'NN'),
#  ('>', 'NN'),
#  ('parties', 'NNS'),
#  ('are', 'VBP'),
#  ('the', 'DT'),
#  ('pucci', 'JJ'),
#  ('woman', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('natural', 'JJ'),
#  ('habitat', 'NN'),
#  (',', ','),
#  ('and', 'CC'),
#  ('miceli', 'JJ'),
#  ('wants', 'VBZ'),
#  ('her', 'PRP$'),
#  ('to', 'TO'),
#  ('shine', 'VB'),
#  ('under', 'IN'),
#  ('the', 'DT'),
#  ('discoballs', 'NNS'),
#  ('.', '.'),
#  ('leggings', 'NNS'),
#  ('with', 'IN'),
#  ('disco', 'NN'),
#  ('ruffles', 'NNS'),
#  ('are', 'VBP'),
#  ('a', 'DT'),
#  ('tribute', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('effervescent', 'JJ'),
#  ('charm', 'NN'),
#  ('of', 'IN'),
#  ('raffaella', 'NN'),
#  ('carrà', 'NN'),
#  (',', ','),
#  ('an', 'DT'),
#  ('italian', 'JJ'),
#  ('showgirl', 'NN'),
#  ('famous', 'JJ'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('’', 'JJ'),
#  ('80s', 'CD'),
#  ('who', 'WP'),
#  ('reminds', 'VBZ'),
#  ('the', 'DT'),
#  ('designer', 'NN'),
#  ('of', 'IN'),
#  ('her', 'PRP$'),
#  ('teenage', 'NN'),
#  ('years', 'NNS'),
#  ('.', '.'),
#  ('miceli', 'JJ'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('affinity', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('label', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('high-style', 'JJ'),
#  ('bohemia', 'NN'),
#  ('was', 'VBD'),
#  ('conveyed', 'VBN'),
#  ('in', 'IN'),
#  ('long', 'RB'),
#  ('printed', 'JJ'),
#  ('chiffon', 'NN'),
#  ('dresses', 'NNS'),
#  ('with', 'IN'),
#  ('ruffled', 'JJ'),
#  ('décolletages', 'NNS'),
#  (',', ','),
#  ('in', 'IN'),
#  ('more', 'RBR'),
#  ('sinuous', 'JJ'),
#  (',', ','),
#  ('body-con', 'JJ'),
#  ('options', 'NNS'),
#  ('wrapped', 'VBD'),
#  ('in', 'IN'),
#  ('stoles', 'NNS'),
#  (',', ','),
#  ('or', 'CC'),
#  ('else', 'RB'),
#  ('in', 'IN'),
#  ('leopard-printed', 'JJ'),
#  ('satiny', 'JJ'),
#  ('numbers', 'NNS'),
#  ('—', 'VBP'),
#  ('a', 'DT'),
#  ('new', 'JJ'),
#  ('introduction', 'NN'),
#  ('as', 'IN'),
#  ('“', 'NN'),
#  ('emilio', 'IN'),
#  ('only', 'RB'),
#  ('did', 'VBD'),
#  ('zebra', 'NN'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('time', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('said', 'VBD'),
#  ('miceli', 'NN'),
#  ('.', '.'),
#  ('“', 'NN'),
#  ('i', 'JJ'),
#  ('love', 'VBP'),
#  ('leopard', 'RB'),
#  ('print', 'NN'),
#  (',', ','),
#  ('i', 'JJ'),
#  ('think', 'VBP'),
#  ('it', 'PRP'),
#  ('’', 'VBZ'),
#  ('s', 'VBZ'),
#  ('a', 'DT'),
#  ('classic', 'JJ'),
#  (',', ','),
#  ('and', 'CC'),
#  ('i', 'RB'),
#  ('believe', 'VBP'),
#  ('it', 'PRP'),
#  ('works', 'VBZ'),
#  ('very', 'RB'),
#  ('well', 'RB'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('psychedelic', 'JJ'),
#  ('prints', 'NNS'),
#  ('from', 'IN'),
#  ('emilio', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('stated', 'VBD'),
#  ('miceli', 'NN'),
#  ('.', '.'),
#  ('conviction', 'NN'),
#  ('is', 'VBZ'),
#  ('definitely', 'RB'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('step', 'NN'),
#  ('towards', 'NNS'),
#  ('success.', 'VBP'),
#  ('<', 'NNP'),
#  ('/p', 'NNP'),
#  ('>', 'NNP'),
#  ('<', 'NNP'),
#  ('/div', 'NNP'),
#  ('>', 'NN')]

# %%
import nltk
from nltk.tag import StanfordNERTagger
from nltk.tokenize import word_tokenize

# Set up Stanford NER Tagger
st = StanfordNERTagger('english.all.3class.distsim.crf.ser.gz')

# Sample text
text = collections['text'][13293]

# Tokenize the text
tokens = word_tokenize(text)

# Tag the tokens with named entity tags
tags = st.tag(tokens)

# Filter out tokens that are not proper nouns
filtered_tokens = [token for token, tag in tags if tag != 'PERSON']

# Join the filtered tokens back into a string
filtered_text = ' '.join(filtered_tokens)

print(filtered_text)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[76], line 6
#       3 from nltk.tokenize import word_tokenize
#       5 # Set up Stanford NER Tagger
# ----> 6 st = StanfordNERTagger('english.all.3class.distsim.crf.ser.gz')
#       8 # Sample text
#       9 text = collections['text'][13293]
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/tag/stanford.py:200, in StanfordNERTagger.__init__(self, *args, **kwargs)
#     199 def __init__(self, *args, **kwargs):
# --> 200     super().__init__(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/tag/stanford.py:70, in StanfordTagger.__init__(self, model_filename, path_to_jar, encoding, verbose, java_options)
#      64 if not self._JAR:
#      65     warnings.warn(
#      66         "The StanfordTagger class is not meant to be "
#      67         "instantiated directly. Did you mean "
#      68         "StanfordPOSTagger or StanfordNERTagger?"
#      69     )
# ---> 70 self._stanford_jar = find_jar(
#      71     self._JAR, path_to_jar, searchpath=(), url=_stanford_url, verbose=verbose
#      72 )
#      74 self._stanford_model = find_file(
#      75     model_filename, env_vars=("STANFORD_MODELS",), verbose=verbose
#      76 )
#      78 self._encoding = encoding
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/internals.py:833, in find_jar(name_pattern, path_to_jar, env_vars, searchpath, url, verbose, is_regex)
#     824 def find_jar(
#     825     name_pattern,
#     826     path_to_jar=None,
#    (...)
#     831     is_regex=False,
#     832 ):
# --> 833     return next(
#     834         find_jar_iter(
#     835             name_pattern, path_to_jar, env_vars, searchpath, url, verbose, is_regex
#     836         )
#     837     )
#
# File ~/anaconda3/lib/python3.11/site-packages/nltk/internals.py:821, in find_jar_iter(name_pattern, path_to_jar, env_vars, searchpath, url, verbose, is_regex)
#     816     msg += "\n\n  For more information, on {}, see:\n    <{}>".format(
#     817         name_pattern,
#     818         url,
#     819     )
#     820 div = "=" * 75
# --> 821 raise LookupError(f"\n\n{div}\n{msg}\n{div}")
#
# LookupError:
#
# ===========================================================================
#   NLTK was unable to find stanford-ner.jar! Set the CLASSPATH
#   environment variable.
#
#   For more information, on stanford-ner.jar, see:
#     <https://nlp.stanford.edu/software>
# ===========================================================================

# %%
collections['text'][13293]
# Out:
# 'True to her Italian roots, Camille Miceli called Pucci’s winter collection <em>La Piazzetta</em>, hinting not only at Capri’s famous handkerchief-sized hotspot, but also at the notion of the city square as part of Italian culture, a space open to communality and connections. These values and the idea of <em>la famiglia</em>, another established building block of the Italian lifestyle, are the drivers Miceli is embracing to charge Pucci with a bold new energy.</p><p>Miceli drew from her own family and circle of friends—a motley crew of characters, talents, and generations—for the winter collection, generously sprinkling it with her abundant <em>joie de vivre</em>. “My Pucci woman is an urban bohemian, she loves to travel, she’s in constant movement,” she says. “It’s the mother, it’s the daughter, it’s the grandma—as long as they enjoy life, they’re part of the community of Pucci.”</p><p>Festive, bold, and colorful, the collection keeps all the label’s fundamentals alive, while introducing a few novelty notes to the mix. Knitwear was a new addition, offered in a rainbow-colored capelet with an undulating hem, or in a fringed hand-knitted, patch-worked poncho worked with horizontal intarsia. Miceli said that she was “happy to have achieved something that is Pucci, without being logo-ed by the prints in a big way.” She also used black as a thread throughout the collection, using prints as pipings, side inserts, foulard ribbons, and fringes, while widening the color palette with “some more options that reflect its character without being necessarily full-on printed.”</p><div class="AdWrapper-dQtivb fZrssQ ad ad--in-content"><div class="ad__slot ad__slot--in-content" data-node-id="yt1iwh"></div></div><p>Fringes are a Miceli signature, as they “bring frivolity to the garment,” she explained. They also give the feel of the  energy and glamour that is the quintessential combination of the Pucci-Miceli connection. The Pucci woman, whatever her age, is on the move, going around in activewear-inspired zippered blousons in shiny recycled nylon printed and tiny pleated printed kilts, and weathering rainy days in protective hooded waxed ponchos boasting the lysergic <em>Marmo</em> pattern.</p><p>Parties are the Pucci woman’s natural habitat, and Miceli wants her to shine under the discoballs. Leggings with disco ruffles are a tribute to the effervescent charm of Raffaella Carrà, an Italian showgirl famous in the ’80s who reminds the designer of her teenage years. Miceli’s affinity for the label’s high-style bohemia was conveyed in long printed chiffon dresses with ruffled décolletages, in more sinuous, body-con options wrapped in stoles, or else in leopard-printed satiny numbers — a new introduction as “Emilio only did zebra at the time,” said Miceli. “I love leopard print, I think it’s a classic, and I believe it works very well with the psychedelic prints from Emilio,” stated Miceli. Conviction is definitely the first step towards success.</p></div>'

# %%
# create a word frequency dataframe
term_frequency = (sample_tokens
                  .groupby(by=['id', 'tokens'])
                  .agg({'tokens': 'count'})
                  .rename(columns={'tokens': 'term_frequency'})
                  .reset_index()
                  .rename(columns={'tokens': 'term'})
                 )

term_frequency.sort_values('term_frequency', ascending = False)[25:40]
# Out:
#             id      term  term_frequency
# 1614158  14070     heart              10
# 1133268  10619     dough              10
# 1301054  11874       hai              10
# 904684    8855      look              10
# 1500875  13293      mice              10
# 991092    9533     roust              10
# 1585352  13880   embroid              10
# 1573654  13798    merhej              10
# 1633716  14207      hors              10
# 1506026  13328   subkoff              10
# 1401438  12599     viard              10
# 1322332  12034     risso              10
# 1436092  12838  monogram              10
# 1622296  14128        ny              10
# 1303383  11891     peter              10

# %%
term_frequency['term'].unique()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[77], line 1
# ----> 1 term_frequency['term'].unique()
#
# NameError: name 'term_frequency' is not defined

# %%
# Document Frequency
document_frequency = (term_frequency
                      .groupby(['id', 'term'])
                      .size()
                      .unstack()
                      .sum()
                      .reset_index()
                      .rename(columns={0: 'document_frequency'})
                     )

# merge dataframes
term_frequency = term_frequency.merge(document_frequency)

documents_in_corpus = term_frequency['id'].nunique()

term_frequency['idf'] = np.log((1 + documents_in_corpus) / (1 + term_frequency['document_frequency'])) + 1
term_frequency['tfidf'] = term_frequency['term_frequency'] * term_frequency['idf']

# %%
from sklearn import preprocessing
term_frequency['tfidf_norm'] = preprocessing.normalize(term_frequency[['tfidf']], axis=0, norm='l2')
term_frequency.sort_values(by=['tfidf_norm'], ascending=[False]).groupby(['term']).head()
# Out:
#             id       term  term_frequency  document_frequency       idf  \
# 1641293  14031    abijako              14                 1.0  9.872207
# 1608708   7466      osakw              13                11.0  8.080447
# 642465    7076     review              19               179.0  5.372397
# 1638793  13296    linnetz              11                 5.0  8.773594
# 1635109  13554    rembert              11                 5.0  8.773594
# ...        ...        ...             ...                 ...       ...
# 1436919  13767     conjur               1               347.0  4.713151
# 462827    2949   accessor               1               357.0  4.684821
# 462831    3046   accessor               1               357.0  4.684821
# 961846   13764  strongest               1               363.0  4.668200
# 961845   13602  strongest               1               363.0  4.668200
#
#               tfidf  tfidf_norm
# 1641293  138.210895    0.019152
# 1608708  105.045815    0.014556
# 642465   102.075545    0.014144
# 1638793   96.509539    0.013373
# 1635109   96.509539    0.013373
# ...             ...         ...
# 1436919    4.713151    0.000653
# 462827     4.684821    0.000649
# 462831     4.684821    0.000649
# 961846     4.668200    0.000647
# 961845     4.668200    0.000647
#
# [110564 rows x 7 columns]

# %% [markdown]
# ### Fitting a Naive Bayes classifier to evaluate word significance and predict class of designer based on collection description
# Using the collections dataframe, we use a supervised learning algorithm to classify the designer collections.

# %%
# check for seasons that only have one datapoint

collections['designer'].value_counts()
# Out:
# designer
# comme-des-garcons    65
# versace              61
# prada                57
# alexander-mcqueen    57
# miu-miu              55
#                      ..
# joy-cioci             1
# jayson-brunsdon       1
# lala-berlin           1
# laurel                1
# marco-rambaldi        1
# Name: count, Length: 1285, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, f1_score, roc_curve, auc
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from nltk.tokenize import word_tokenize, WhitespaceTokenizer, TweetTokenizer

subset = collections[collections['designer']>1990.1]

X = subset['preprocessed_sentences']
y = subset['designer']

X_train, X_test, y_train, y_test = train_test_split(X, y, stratify = y)

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
y_train_le = label_encoder.fit_transform(y_train)
y_test_le = label_encoder.transform(y_test)

print(f'Label encoded training labels shape: {y_train_le.shape}')
print(f'Label encoded validation labels shape: {y_test_le.shape}')
# Out:
# Label encoded training labels shape: (10693,)
# Label encoded validation labels shape: (3565,)

# %%
# Naive Bayes
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.feature_extraction.text import CountVectorizer

cv = CountVectorizer()
X_train = cv.fit_transform(X_train.values)
X_test = cv.transform(X_test.values)

nb_model =  MultinomialNB()
nb_model.fit(X_train, y_train_le)

# Predict the authors of validation dataset
nb_predictions = nb_model.predict(X_test)

print(nb_model.score(X_test, y_test_le))
# Out:
# 0.13071528751753156

# %%
import tensorflow as tf
import tensorflow_datasets as tfds

dataset = tf.data.Dataset.from_tensor_slices((sentences, labels))
